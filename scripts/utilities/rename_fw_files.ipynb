# %% [markdown]
# # Correcting Misnamed Fieldmap Scans on Flywheel
#
# *Project: Evolution_833922* <br>
# _Author: Katja Zoner_ <br>
# _Updated: 05/05/2021_ <br>
#
# Notebook to correct the misnamed dir-AP acq-dwi fieldmap scans across the Flywheel project. The dir-AP scans were mistakenly named dir-PA at the scanner. This script identifies the dir-AP scans via the `PhaseEndodingDirection` field (for nifti files) and `PhaseEncodingDirectionPositive` field (for dicom files), then corrects the acquisition labe, `ProtocolName`, and `SeriesDescription` from `fmap-EPIdist_acq-dwi_dir-PA_seq-ABCD` to `map-EPIdist_acq-dwi_dir-AP_seq-ABCD`.
#
# **Direction is AP if:** <br>
# `PhaseEndodingDirection`:           'j-'    (nifti) <br>
# `PhaseEndodingDirectionPositive`:    1      (dicom)

# %% [markdown]
# ## 0. Import packages and setup logging.

# %%
import flywheel
import logging
import sys

# Set up logging
logging.basicConfig(
    stream=sys.stdout,
    level=logging.INFO,
    format='%(levelname)s: %(message)s')
logger = logging.getLogger('rename_fw_files')

# %% [markdown]
# ## 1. Instantiate Flywheel client, get project object.

# %%
# Get client
fw = flywheel.Client()
assert fw, "Your Flywheel CLI credentials aren't set!"

# Specify project
project_label = "Evolution_833922"

# Get project object
project = fw.projects.find_first('label="{}"'.format(project_label))
assert project, "Project not found!"

# %% [markdown]
# ## 2. Some helpful functions...

# %%
def get_sessions(session_labels=None):
    ''' Return a list of session objects corresponding to the 
        optionally-specified session labels. 
        Default: return all session objects in project.

    Args:
        session_labels (list of str) : List of session labels
    
    Returns:
        sessions: list of session objects
    '''

    # Get all sessions in project
    sessions = project.sessions()

    # Filter by optionally-specified session label list
    if session_labels:
        sessions = [s for s in sessions if s.label in session_labels]

    return sessions

# %%
def update_acq_label(acq_id, new_label):
    '''Update the acquisition label on the project container.

    Args:
        acq_id (str) : Acquisition ID
        new_label (str) : Updated Acquisition Label

    '''
    new_acq_object = flywheel.models.Acquisition(label = new_label)
    # Modifying the acquisition label here 
    fw.modify_acquisition(acquisition_id= acq_id, body = new_acq_object)

# %% [markdown]
# ## 3. Main Program
#
# 1. Loop through sessions
# 2. Loop through fmap acq-dwi acquisitions
# 3. Identify AP scans
# 4. Fix 'ProtocolName' and 'SeriesDescription' in file metadata for AP scans
# 5. Fix acquisition label for AP acquisitions

# %%
## Main Program

# Specify sessions (optional)
#session_labels = ["BRAIN RESEARCH^SATTERTHWAITE"]
sessions = get_sessions()

# New label for AP acquisitions, ProtocolName, and SeriesDescription
AP_label='fmap-EPIdist_acq-dwi_dir-AP_seq-ABCD'

#countAP=0
#countPA=0

# Loop through each session
for sess in sessions:

    # Loop through fmap acq-dwi acquisitions (dir-AP or dir-PA)
    for acq in sess.acquisitions.find('label=~fmap-EPIdist_acq-dwi_dir-.._seq-ABCD'):
        
        acq = acq.reload()  # Can't load metadata without this line!!!
        hasAP = False       # Bool to indicate whether or not to rename this acquisition

        # Loop through files in acquisition
        for file in acq.files:

            # Check metadata field to determine if scan direction is AP
            # Dicom scans have 'PhaseEncodingDirectionPositive' field instead of 'PhaseEncodingDirection' field
            try:
                isAP = (file.info['PhaseEncodingDirection'] == 'j-')
            except KeyError:
                isAP = (file.info['CSAHeader']['PhaseEncodingDirectionPositive'] == 1)
            
            # If AP scan -> correct protocol name and series description in file metadata 
            if isAP:
                #countAP+=1
                hasAP = True
                logger.info(f"Correcting metadata for scan {file.name} in session {sess.label}")
                file.update_info({'ProtocolName': AP_label, 'SeriesDescription': AP_label})
            
            # If PA scan -> update count
            #else:
                #countPA+=1
        
        # If acquisition consists of AP scans -> update acquisition label
        if hasAP:
            logger.info(f"Renaming acquisition {acq.id} in session {sess.label}")
            update_acq_label(acq.id, AP_label)


#print(countAP)
#print(countPA)
# Out:
# 67024.2020082616491492215139788.0.0.0.nii.gz in session 11524
# INFO: Renaming acquisition 5f46ca80bcc88ccfc2a1ba27 in session 11524
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2020083118481177612104167.0.0.0.dicom.zip in session 11527
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2020083118481177612104167.0.0.0.nii.gz in session 11527
# INFO: Renaming acquisition 5f4d7dea3941cbadcf4689dd in session 11527
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2020090316481361477858953.0.0.0.dicom.zip in session 11528
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2020090316481361477858953.0.0.0.nii.gz in session 11528
# INFO: Renaming acquisition 5f51563992f4d32fbe4b9275 in session 11528
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2020090811591279862717604.0.0.0.dicom.zip in session 11529
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2020090811591279862717604.0.0.0.nii.gz in session 11529
# INFO: Renaming acquisition 5f57aa25efb6c911c3c06a06 in session 11529
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2020091017491687470091281.0.0.0.dicom.zip in session 11532
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2020091017491687470091281.0.0.0.nii.gz in session 11532
# INFO: Renaming acquisition 5f5a9f0cb4e7ef8afe4b94af in session 11532
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2020091512084659952721579.0.0.0.dicom.zip in session 11534
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2020091512084659952721579.0.0.0.nii.gz in session 11534
# INFO: Renaming acquisition 5f60e6c75f6f2f4d754b912c in session 11534
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2020092114364065041868944.0.0.0.dicom.zip in session 11539
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2020092114364065041868944.0.0.0.nii.gz in session 11539
# INFO: Renaming acquisition 5f68f254e5f327d223275709 in session 11539
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2020100212492847520617899.0.0.0.dicom.zip in session 11544
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2020100212492847520617899.0.0.0.nii.gz in session 11544
# INFO: Renaming acquisition 5f7759dbda6d2b2d74c6186d in session 11544
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2020100713312910330837669.0.0.0.dicom.zip in session 11551
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2020100713312910330837669.0.0.0.nii.gz in session 11551
# INFO: Renaming acquisition 5f7dfb143434f2e0b8c61887 in session 11551
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2020100912361431659317027.0.0.0.dicom.zip in session 11552
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2020100912361431659317027.0.0.0.nii.gz in session 11552
# INFO: Renaming acquisition 5f809133f050f6de64c61696 in session 11552
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2020101413364189621478828.0.0.0.dicom.zip in session 11557
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2020101413364189621478828.0.0.0.nii.gz in session 11557
# INFO: Renaming acquisition 5f8736c15d0dca2e4850ce0e in session 11557
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2020101511301475328208573.0.0.0.dicom.zip in session 11558
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2020101511301475328208573.0.0.0.nii.gz in session 11558
# INFO: Renaming acquisition 5f886a9e029ece64ada8c6c1 in session 11558
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.202010191616212569735593.0.0.0.dicom.zip in session 11560
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.202010191616212569735593.0.0.0.nii.gz in session 11560
# INFO: Renaming acquisition 5f8df3c399cca07e90990eb9 in session 11560
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2020102215493391641154257.0.0.0.dicom.zip in session 11563
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2020102215493391641154257.0.0.0.nii.gz in session 11563
# INFO: Renaming acquisition 5f91e1f1d2000049b2a8c78a in session 11563
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2020102815483730559781425.0.0.0.dicom.zip in session 11568
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2020102815483730559781425.0.0.0.nii.gz in session 11568
# INFO: Renaming acquisition 5f99ca90efff2c1753991123 in session 11568
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2020110413512529186469042.0.0.0.dicom.zip in session 11571
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2020110413512529186469042.0.0.0.nii.gz in session 11571
# INFO: Renaming acquisition 5fa2f7a32921a3b8beb08b42 in session 11571
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2020110613383955849332831.0.0.0.dicom.zip in session 11575
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2020110613383955849332831.0.0.0.nii.gz in session 11575
# INFO: Renaming acquisition 5fa597b30c8c12dc1ef358dc in session 11575
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2020111119255191359853884.0.0.0.dicom.zip in session 11581
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2020111119255191359853884.0.0.0.nii.gz in session 11581
# INFO: Renaming acquisition 5fac80a5b0511acfaee330cc in session 11581
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2020111210570547348285483.0.0.0.dicom.zip in session 11582
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2020111210570547348285483.0.0.0.nii.gz in session 11582
# INFO: Renaming acquisition 5fad5ae3f2b0efdae5e33133 in session 11582
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2020111719212979408041590.0.0.0.dicom.zip in session 11585
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2020111719212979408041590.0.0.0.nii.gz in session 11585
# INFO: Renaming acquisition 5fb4688c8873c4792ba14d41 in session 11585
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2020112013270780970497752.0.0.0.dicom.zip in session 11587
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2020112013270780970497752.0.0.0.nii.gz in session 11587
# INFO: Renaming acquisition 5fb80a2b657b288c6b6879fe in session 11587
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.202012011235319369517459.0.0.0.dicom.zip in session 11592
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.202012011235319369517459.0.0.0.nii.gz in session 11592
# INFO: Renaming acquisition 5fc67e6d0b4fb38ce9631e59 in session 11592
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2020120315534064974740059.0.0.0.dicom.zip in session 11595
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2020120315534064974740059.0.0.0.nii.gz in session 11595
# INFO: Renaming acquisition 5fc94fccfd6e0fb7a46320a9 in session 11595
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2020120713204685574755404.0.0.0.dicom.zip in session 11597
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2020120713204685574755404.0.0.0.nii.gz in session 11597
# INFO: Renaming acquisition 5fce7208b4d3b1d47c631f1c in session 11597
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2020120918523063800172575.0.0.0.dicom.zip in session 11598
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2020120918523063800172575.0.0.0.nii.gz in session 11598
# INFO: Renaming acquisition 5fd162cb7dbdeebf0d63201f in session 11598
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2020121017430679507406507.0.0.0.dicom.zip in session 11600
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2020121017430679507406507.0.0.0.nii.gz in session 11600
# INFO: Renaming acquisition 5fd2a3d287e2185dbb9f6e6e in session 11600
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.20201212143444421756328.0.0.0.dicom.zip in session 11602
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.20201212143444421756328.0.0.0.nii.gz in session 11602
# INFO: Renaming acquisition 5fd51aa90edcb9dc2c9f6d7f in session 11602
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2020121511205853870414717.0.0.0.dicom.zip in session 11609
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2020121511205853870414717.0.0.0.nii.gz in session 11609
# INFO: Renaming acquisition 5fd8e1ed1e001f47b6575d04 in session 11609
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2020121611411135724311709.0.0.0.dicom.zip in session 11613
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2020121611411135724311709.0.0.0.nii.gz in session 11613
# INFO: Renaming acquisition 5fda37fcf189243360e7df45 in session 11613
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2021011113062571111120254.0.0.0.dicom.zip in session 11619
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2021011113062571111120254.0.0.0.nii.gz in session 11619
# INFO: Renaming acquisition 5ffc94661d287e75bb32d1ac in session 11619
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2021011215300919389963732.0.0.0.dicom.zip in session 11621
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2021011215300919389963732.0.0.0.nii.gz in session 11621
# INFO: Renaming acquisition 5ffe0789ed4bd5b739837907 in session 11621
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2021011313365758464936133.0.0.0.dicom.zip in session 11623
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2021011313365758464936133.0.0.0.nii.gz in session 11623
# INFO: Renaming acquisition 5fff3ead833a696296837780 in session 11623
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2021011914505377693918030.0.0.0.dicom.zip in session 11627
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2021011914505377693918030.0.0.0.nii.gz in session 11627
# INFO: Renaming acquisition 600738f572891765118497f8 in session 11627
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2021012014175425925188649.0.0.0.dicom.zip in session 11629
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2021012014175425925188649.0.0.0.nii.gz in session 11629
# INFO: Renaming acquisition 600882ce0eb96a4c9dcca780 in session 11629
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2021012112541190195669757.0.0.0.dicom.zip in session 11630
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2021012112541190195669757.0.0.0.nii.gz in session 11630
# INFO: Renaming acquisition 6009c07a41a91b82e4849c14 in session 11630
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2021012512133581612274311.0.0.0.dicom.zip in session 11636
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2021012512133581612274311.0.0.0.nii.gz in session 11636
# INFO: Renaming acquisition 600efcf5069f319c70eac941 in session 11636
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2021012613142659606337653.0.0.0.dicom.zip in session 11637
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2021012613142659606337653.0.0.0.nii.gz in session 11637
# INFO: Renaming acquisition 60105cd64303b8970984980b in session 11637
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2021012713104066175544664.0.0.0.dicom.zip in session 22639
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2021012713104066175544664.0.0.0.nii.gz in session 22639
# INFO: Renaming acquisition 6022f519cb0391504aef2cae in session 22639
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2021020513014054424488472.0.0.0.dicom.zip in session 11645
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2021020513014054424488472.0.0.0.nii.gz in session 11645
# INFO: Renaming acquisition 60233cf277a8962a2c85b647 in session 11645
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2021020814351841999324157.0.0.0.dicom.zip in session 11646
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2021020814351841999324157.0.0.0.nii.gz in session 11646
# INFO: Renaming acquisition 602346bed88dc8b30562270e in session 11646
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2021020913244518012293500.0.0.0.dicom.zip in session 11647
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2021020913244518012293500.0.0.0.nii.gz in session 11647
# INFO: Renaming acquisition 6023596a67e71da6ae85ba01 in session 11647
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2021021014552452644727706.0.0.0.dicom.zip in session 11648
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2021021014552452644727706.0.0.0.nii.gz in session 11648
# INFO: Renaming acquisition 60243ad687f49fba6785b97b in session 11648
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2021021613211489171034092.0.0.0.dicom.zip in session 11653
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2021021613211489171034092.0.0.0.nii.gz in session 11653
# INFO: Renaming acquisition 602c0daf2061fa107be2d8d7 in session 11653
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.202102171120402923197353.0.0.0.dicom.zip in session 11654
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.202102171120402923197353.0.0.0.nii.gz in session 11654
# INFO: Renaming acquisition 602d431db09d0cf6e22c1543 in session 11654
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2021022010293138158740502.0.0.0.dicom.zip in session 11655
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2021022010293138158740502.0.0.0.nii.gz in session 11655
# INFO: Renaming acquisition 60312b8d390b376f81933d16 in session 11655
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2021022011425462557470940.0.0.0.dicom.zip in session 11656
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2021022011425462557470940.0.0.0.nii.gz in session 11656
# INFO: Renaming acquisition 60313ca7ad03dbcb312c139f in session 11656
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2021030115403271844772892.0.0.0.dicom.zip in session 11668
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2021030115403271844772892.0.0.0.nii.gz in session 11668
# INFO: Renaming acquisition 603d524196bc7a479e89361e in session 11668
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2021030313531311846768839.0.0.0.dicom.zip in session 11671
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2021030313531311846768839.0.0.0.nii.gz in session 11671
# INFO: Renaming acquisition 603fdbf9b768fd8f1789329a in session 11671
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2021030413131464239213096.0.0.0.dicom.zip in session 11673
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2021030413131464239213096.0.0.0.nii.gz in session 11673
# INFO: Renaming acquisition 6041244214dca5ac57d8dfad in session 11673
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2021031113304619661660426.0.0.0.dicom.zip in session 11688
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2021031113304619661660426.0.0.0.nii.gz in session 11688
# INFO: Renaming acquisition 604a62c4017a83f65cc85383 in session 11688
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2021031214461772851982464.0.0.0.dicom.zip in session 11689
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2021031214461772851982464.0.0.0.nii.gz in session 11689
# INFO: Renaming acquisition 604bc5f3afbd2f647bd8d986 in session 11689
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2021031514035779177408622.0.0.0.dicom.zip in session 11691
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2021031514035779177408622.0.0.0.nii.gz in session 11691
# INFO: Renaming acquisition 604fa293e376745cbdd8d896 in session 11691
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2021031613173050976756108.0.0.0.dicom.zip in session 11693
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2021031613173050976756108.0.0.0.nii.gz in session 11693
# INFO: Renaming acquisition 6050e91182ffbbcce2c84d53 in session 11693
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2021031813322451024713094.0.0.0.dicom.zip in session 11696
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2021031813322451024713094.0.0.0.nii.gz in session 11696
# INFO: Renaming acquisition 60538f940c76affd52d8d814 in session 11696
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2021032612144975237491115.0.0.0.dicom.zip in session 11700
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2021032612144975237491115.0.0.0.nii.gz in session 11700
# INFO: Renaming acquisition 605e095ff48c874c7fd8d694 in session 11700
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2021040112393616167250727.0.0.0.dicom.zip in session 11710
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2021040112393616167250727.0.0.0.nii.gz in session 11710
# INFO: Renaming acquisition 6065f8137e7d51e2aac84faa in session 11710
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2021040213121730839051783.0.0.0.dicom.zip in session 11711
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2021040213121730839051783.0.0.0.nii.gz in session 11711
# INFO: Renaming acquisition 606751408eaed82683e53ed8 in session 11711
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2021040613120239935425197.0.0.0.dicom.zip in session 11712
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2021040613120239935425197.0.0.0.nii.gz in session 11712
# INFO: Renaming acquisition 606c974a71d6c1d230a165a8 in session 11712
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2021041011433387282906922.0.0.0.dicom.zip in session 11715
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2021041011433387282906922.0.0.0.nii.gz in session 11715
# INFO: Renaming acquisition 6071c89bf3d5ee643c6512f2 in session 11715
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2021041611301954656823434.0.0.0.dicom.zip in session 11721
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2021041611301954656823434.0.0.0.nii.gz in session 11721
# INFO: Renaming acquisition 6079ae7560b6bbf359651080 in session 11721
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2021042015270341058029312.0.0.0.dicom.zip in session 11725
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2021042015270341058029312.0.0.0.nii.gz in session 11725
# INFO: Renaming acquisition 607f2be1c9eebab6e6e9b094 in session 11725
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2021042113432933933675162.0.0.0.dicom.zip in session 11727
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2021042113432933933675162.0.0.0.nii.gz in session 11727
# INFO: Renaming acquisition 60806510394dce904ee9b367 in session 11727
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2021042213423885039805208.0.0.0.dicom.zip in session 11730
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2021042213423885039805208.0.0.0.nii.gz in session 11730
# INFO: Renaming acquisition 6081b65a2f7b09ff84bd6eda in session 11730
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2021042315384069115004471.0.0.0.dicom.zip in session BRAIN RESEARCH^BBL
# INFO: Renaming acquisition 60832329d366954e1c03a954 in session BRAIN RESEARCH^BBL
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2021042813174229828333632.0.0.0.dicom.zip in session BRAIN RESEARCH^BBL
# INFO: Renaming acquisition 608999860ffd9de57f086ffb in session BRAIN RESEARCH^BBL
# INFO: Correcting metadata for scan 1.3.12.2.1107.5.2.43.167024.2021050315490733594992884.0.0.0.dicom.zip in session BRAIN RESEARCH^BBL
# INFO: Renaming acquisition 6090547bf90c56dfdea19fe3 in session BRAIN RESEARCH^BBL
# 186
# 172
